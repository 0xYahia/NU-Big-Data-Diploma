# %% [markdown]
# # Colab
#
#
# *   ##  mount drive
#
# *   ## download from link directly to your drive
#
# *   ## unzip a folder in drive

# %%
# # to be able to read and add files to your google drive
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
#!pip install wget

# %%
# #download from a link

# import wget
# url =  '' ## the download link
# destination = '/content/drive/My Drive/CIT651/heart.zip'
# wget.download(url, destination)

# %%
# #UnZip file on drive

# import zipfile
# zip_ref = zipfile.ZipFile('/content/drive/My Drive/CIT651/heart.zip', 'r')
# zip_ref.extractall('/content/drive/My Drive/CIT651/')
# zip_ref.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #  **Pandas**

# %% [markdown]
# # Read CSV, Crosstab

# %%
# start with pandas
import pandas as pd

# %%
#read csv file

file = '/content/drive/MyDrive/machine learning post/pandas/heart.csv'
table = pd.read_csv(file)

# %%
table
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # Display records, shapes and data types

# %% [markdown]
#  **Display the shape and the size of the table**

# %% [markdown]
# * **shape**

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
table.shape
# Out:
# (303, 14)

# %% [markdown]
# * **size:** total number of cells

# %%
table.size
# Out:
# 4242

# %% [markdown]
# * **number of samples in the dataset**

# %%
len(table)
# Out:
# 303

# %% [markdown]
# * **print columns names**

# %%
table.columns    ## table.keys() gets the same result
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# * **print columns data types**

# %%
table.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
table.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# * **display the last 3 records of the table**

# %%
table.tail(3)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
# # Selection

# %% [markdown]
# * **select the age column**

# %%
table['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %% [markdown]
# * **select the first 3 rows in the age column**

# %%
table['age'][:3]
# Out:
# 0    63
# 1    37
# 2    41
# Name: age, dtype: int64

# %% [markdown]
# * **select age, fbs and target columns**

# %%
table[["age", 'fbs', 'target']]
# Out:
#      age  fbs  target
# 0     63    1       1
# 1     37    0       1
# 2     41    0       1
# 3     56    0       1
# 4     57    0       1
# ..   ...  ...     ...
# 298   57    0       0
# 299   45    0       0
# 300   68    1       0
# 301   57    0       0
# 302   57    0       0
#
# [303 rows x 3 columns]

# %% [markdown]
# * **select age, fbs and target columns and rows from 10 to 15:** use both loc and iloc
#
# ** **Note**: The main distinction between loc and iloc is:
# loc is label-based, which means that you have to specify rows and columns based on their row and column labels.
# iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).

# %%
table.loc[10:15,["age", 'fbs', 'target']]
#table[["age", 'fbs', 'target']][10:15]
# Out:
#     age  fbs  target
# 10   54    0       1
# 11   48    0       1
# 12   49    0       1
# 13   64    0       1
# 14   58    1       1
# 15   50    0       1

# %%
table.iloc[10:15,[0, 5, 13]]
# Out:
#     age  fbs  target
# 10   54    0       1
# 11   48    0       1
# 12   49    0       1
# 13   64    0       1
# 14   58    1       1

# %% [markdown]
# # Value counts

# %% [markdown]
# ## Get the number of heart attack and non heart attack samples in the data
# * **use value_counts()**

# %%
table.target.value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
table.sex.value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %% [markdown]
# * **get their probabilites from the dataset**

# %%
table.target.value_counts()/len(table)
# Out:
# 1    0.544554
# 0    0.455446
# Name: target, dtype: float64

# %% [markdown]
# * ### get the probabilities of each gender of people with heart attack

# %%
table[table.target == 1].sex.value_counts()/len(table[table.target == 1])
# Out:
# 1    0.563636
# 0    0.436364
# Name: sex, dtype: float64

# %%
### get the probabilities of heart vs no heart attack in the males

# %%
table[table.sex == 1].target.value_counts()/len(table[table.sex == 1])
# Out:
# 0    0.550725
# 1    0.449275
# Name: target, dtype: float64

# %% [markdown]
# # Crosstab

# %%
pd.crosstab(table.sex, table.target,margins = True)
# Out:
# target    0    1  All
# sex
# 0        24   72   96
# 1       114   93  207
# All     138  165  303

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# * **rename target 1 to 'yes', and 0 to 'no'**
# * **rename gender 1 to 'male', and 0 to 'female'**

# %%
#Solution 1
table['gender'] = table['sex'].map({1: 'Male', 0: 'Female'})
table['attack'] = table['target'].map({1:'Yes' ,0: 'No'})
gender_attack=pd.crosstab(table.gender, table.attack, margins = True)
gender_attack
# Out:
# attack   No  Yes  All
# gender
# Female   24   72   96
# Male    114   93  207
# All     138  165  303

# %%
#Solution 2
table['gender'] = table['sex'].map(lambda x: 'Male' if x==1 else 'Female')
table['attack'] = table['target'].map(lambda x: 'Yes' if x ==1 else 'No')
gender_attack = pd.crosstab(table.gender, table.attack, margins = True)
gender_attack
# Out:
# attack   No  Yes  All
# gender
# Female   24   72   96
# Male    114   93  207
# All     138  165  303

# %%
gender_attack.loc['Female','Yes']/gender_attack.loc['All','Yes']
# Out:
# 0.43636363636363634

# %%
gender_attack.iloc[0,1]/gender_attack.iloc[2,1]
# Out:
# 0.43636363636363634

# %% [markdown]
# ***Exercise***
#
# fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# * create new column 'bloodSugar' with values 'Yes' or 'No'
#
# cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# * convert chest pain column values to their corresponding meanings

# %%
## code here
table['bloodSugar'] = table['fbs'].map(lambda x: 'Male' if x==1 else 'Female')

# %%
table['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
dict={0:'typical angina', 1:'atypical angina', 2:'non-anginal pain', 3:'asymptomatic'}
table['chestPain'] = table['cp'].map(lambda x: dict.get(x))

# %%
# another solution
table['chestPain'] = table['cp'].map({0:'typical angina', 1:'atypical angina', 2:'non-anginal pain', 3:'asymptomatic'})

# %%
table
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  gender attack bloodSugar         chestPain
# 0        0   0     1       1    Male    Yes       Male      asymptomatic
# 1        0   0     2       1    Male    Yes     Female  non-anginal pain
# 2        2   0     2       1  Female    Yes     Female   atypical angina
# 3        2   0     2       1    Male    Yes     Female   atypical angina
# 4        2   0     2       1  Female    Yes     Female    typical angina
# ..     ...  ..   ...     ...     ...    ...        ...               ...
# 298      1   0     3       0  Female     No     Female    typical angina
# 299      1   0     3       0    Male     No     Female      asymptomatic
# 300      1   2     3       0    Male     No       Male    typical angina
# 301      1   1     3       0    Male     No     Female    typical angina
# 302      1   1     2       0  Female     No     Female   atypical angina
#
# [303 rows x 18 columns]

# %%
pd.crosstab(table.attack, table.bloodSugar, margins = True)
# Out:
# bloodSugar  Female  Male  All
# attack
# No             116    22  138
# Yes            142    23  165
# All            258    45  303

# %% [markdown]
# * ## plot a stacked bar to visualize the gender vs attack

# %%
pd.crosstab(table.gender, table.attack).plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# [Pandas Crosstab](https://pbpython.com/pandas-crosstab.html)

# %%
df = table[['age', 'target']][:3]
df
# Out:
#    age  target
# 0   63       1
# 1   37       1
# 2   41       1

# %%
df.rename(columns = {'target':'heart_attack'})
# Out:
#    age  heart_attack
# 0   63             1
# 1   37             1
# 2   41             1

# %%
df.T  ## transpose of the table
# Out:
#          0   1   2
# age     63  37  41
# target   1   1   1

# %% [markdown]
# # Addition

# %%
df1 = table[['age', 'target']][:3]
df2 = table[['age', 'target']][3:5]

# %%
df1
# Out:
#    age  target
# 0   63       1
# 1   37       1
# 2   41       1

# %%
df2
# Out:
#    age  target
# 3   56       1
# 4   57       1

# %%
df1.append(df2)
# Out:
# <ipython-input-46-8ab0723181fb>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#    age  target
# 0   63       1
# 1   37       1
# 2   41       1
# 3   56       1
# 4   57       1

# %%
df2
# Out:
#    age  target
# 3   56       1
# 4   57       1

# %% [markdown]
# # Iteration / Sorting

# %%
for key in table:
    print(key)
# Out:
# age
# sex
# cp
# trestbps
# chol
# fbs
# restecg
# thalach
# exang
# oldpeak
# slope
# ca
# thal
# target
# gender
# attack
# bloodSugar
# chestPain

# %%
table[['age', 'target']].sort_values(['target', 'age'])[:5]  ## sort by 'age' column
# Out:
#      age  target
# 227   35       0
# 239   35       0
# 259   38       0
# 212   39       0
# 175   40       0

# %% [markdown]
# # from pandas to numpy

# %%
import numpy as np

# %%
age_cp = table[['age', 'cp']][:3].values

# %%
type(age_cp)
# Out:
# numpy.ndarray

# %%
age_cp
# Out:
# array([[63,  3],
#        [37,  2],
#        [41,  1]])

# %%
table[['age', 'cp']][:3].values
# Out:
# array([[63,  3],
#        [37,  2],
#        [41,  1]])

# %%
df2=pd.DataFrame(np.random.rand(3,3),index=['X','Y','Z'],columns=['C1','C2','C3'])
print(df2)
# Out:
#          C1        C2        C3
# X  0.542104  0.120861  0.543273
# Y  0.490395  0.594632  0.471631
# Z  0.244059  0.877013  0.725569
